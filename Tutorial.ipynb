# %%
import os
import logging, timeit
from btEngine2.DataLoader import DataLoader
from btEngine2.MarketData import MarketData
from btEngine2.TradingRule import TradingRule

# Define paths and configurations for DataLoader
ticker_csv_path = r'G:\Projects\BackTesting1.0\Data\Inputs\TickerList-Futs.csv'
save_directory = r"G:\Projects\BackTesting1.0\Data\Bloomberg\Futures"
helper_directory = r'G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles'
# List of tickers to load
sleep_time = 1  # Seconds to sleep between API calls
max_retries = 10  # Maximum number of retries for API calls
load_carry= True

# Initialize the DataLoader
data_loader = DataLoader(
    ticker_csv_path=ticker_csv_path,
    base_directory=save_directory,
    sleep_time=sleep_time,
    log_level=logging.INFO,  # Set to DEBUG for more detailed logs
    max_retries=max_retries,
    loadCarry=load_carry
)

# Run the data loading process
data_loader.bbgloader()
# Out:
# 2024-10-22 12:05:28,740 INFO DataLoader: Loaded 104 tickers from G:\Projects\BackTesting1.0\Data\Inputs\TickerList-Futs.csv
# 2024-10-22 12:05:28,741 INFO DataLoader: Helper files will be stored in: G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles
# 2024-10-22 12:05:28,742 INFO DataLoader: Starting data loading process...
# 2024-10-22 12:05:28,743 INFO DataLoader: Loaded 104 futures from G:\Projects\BackTesting1.0\Data\Inputs\TickerList-Futs.csv
# 2024-10-22 12:05:30,591 INFO DataLoader: Successfully retrieved fut_val_pt data for 102 assets.
# 2024-10-22 12:05:30,593 INFO DataLoader: Futures value per point data saved to G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles\fut_val_pt.csv
# 2024-10-22 12:05:30,598 INFO DataLoader: Currencies to fetch FX rates for: ['SEK', 'CNH', 'EUR', 'KRW', 'ZAR', 'BRL', 'CZK', 'CHF', 'SGD', 'CAD', 'HKD', 'HUF', 'AUD', 'GBP', 'TRY', 'JPY']
# 2024-10-22 12:05:41,134 INFO DataLoader: Successfully retrieved FX history data for 16 currencies.
# 2024-10-22 12:05:41,225 INFO DataLoader: FX rate history data saved to G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles\fxHist.csv
# 2024-10-22 12:05:41,244 INFO DataLoader: FX rate history data saved to G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles\fxHist.parquet
# 2024-10-22 12:05:41,249 INFO DataLoader: Futures value per point data saved to G:\Projects\BackTesting1.0\Data\Bloomberg\HelperFiles\fut_val_pt.parquet
# Processing tickers:   0%|          | 0/104 [00:00<?, ?ticker/s]2024-10-22 12:05:41,257 INFO DataLoader: Carry column missing for LP1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:05:51,768 WARNING DataLoader: No data returned for ticker LP1 Comdty. Attempt 1/10
# 2024-10-22 12:05:51,769 ERROR DataLoader: Error loading data for LP1 Comdty (Attempt 1/10): No data returned for ticker LP1 Comdty.
# 2024-10-22 12:06:00,424 INFO DataLoader: Successfully loaded data for ticker LP1 Comdty with 6896 records.
# 2024-10-22 12:06:00,426 INFO DataLoader: Calculating Carry for LP1 Comdty using carry contract LP2 Comdty
# 2024-10-22 12:06:11,995 WARNING DataLoader: No data returned for ticker LP2 Comdty. Attempt 1/10
# 2024-10-22 12:06:11,996 ERROR DataLoader: Error loading data for LP2 Comdty (Attempt 1/10): No data returned for ticker LP2 Comdty.
# 2024-10-22 12:06:23,506 WARNING DataLoader: No data returned for ticker LP2 Comdty. Attempt 2/10
# 2024-10-22 12:06:23,507 ERROR DataLoader: Error loading data for LP2 Comdty (Attempt 2/10): No data returned for ticker LP2 Comdty.
# 2024-10-22 12:06:31,486 INFO DataLoader: Successfully loaded data for ticker LP2 Comdty with 6894 records.
# 2024-10-22 12:06:31,491 INFO DataLoader: Carry calculated and added for LP1 Comdty.
# 2024-10-22 12:06:31,510 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-base\LP1 Comdty.parquet
# Processing tickers:   1%|          | 1/104 [00:51<1:27:59, 51.26s/ticker]2024-10-22 12:06:32,522 INFO DataLoader: Carry column missing for LN1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:06:43,034 WARNING DataLoader: No data returned for ticker LN1 Comdty. Attempt 1/10
# 2024-10-22 12:06:43,035 ERROR DataLoader: Error loading data for LN1 Comdty (Attempt 1/10): No data returned for ticker LN1 Comdty.
# 2024-10-22 12:06:46,941 INFO DataLoader: Successfully loaded data for ticker LN1 Comdty with 6877 records.
# 2024-10-22 12:06:46,943 INFO DataLoader: Calculating Carry for LN1 Comdty using carry contract LN2 Comdty
# 2024-10-22 12:06:55,023 WARNING DataLoader: No data returned for ticker LN2 Comdty. Attempt 1/10
# 2024-10-22 12:06:55,023 ERROR DataLoader: Error loading data for LN2 Comdty (Attempt 1/10): No data returned for ticker LN2 Comdty.
# 2024-10-22 12:07:01,559 INFO DataLoader: Successfully loaded data for ticker LN2 Comdty with 6887 records.
# 2024-10-22 12:07:01,563 INFO DataLoader: Carry calculated and added for LN1 Comdty.
# 2024-10-22 12:07:01,578 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-base\LN1 Comdty.parquet
# Processing tickers:   2%|▏         | 2/104 [01:21<1:05:56, 38.79s/ticker]2024-10-22 12:07:02,586 INFO DataLoader: Carry column missing for HG1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:07:04,244 WARNING DataLoader: No data returned for ticker HG1 Comdty. Attempt 1/10
# 2024-10-22 12:07:04,244 ERROR DataLoader: Error loading data for HG1 Comdty (Attempt 1/10): No data returned for ticker HG1 Comdty.
# 2024-10-22 12:07:07,424 INFO DataLoader: Successfully loaded data for ticker HG1 Comdty with 9028 records.
# 2024-10-22 12:07:07,426 INFO DataLoader: Calculating Carry for HG1 Comdty using carry contract HG2 Comdty
# 2024-10-22 12:07:12,068 WARNING DataLoader: No data returned for ticker HG2 Comdty. Attempt 1/10
# 2024-10-22 12:07:12,069 ERROR DataLoader: Error loading data for HG2 Comdty (Attempt 1/10): No data returned for ticker HG2 Comdty.
# 2024-10-22 12:07:18,438 INFO DataLoader: Successfully loaded data for ticker HG2 Comdty with 9029 records.
# 2024-10-22 12:07:18,442 INFO DataLoader: Carry calculated and added for HG1 Comdty.
# 2024-10-22 12:07:18,457 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-base\HG1 Comdty.parquet
# Processing tickers:   3%|▎         | 3/104 [01:38<48:27, 28.79s/ticker]  2024-10-22 12:07:19,466 INFO DataLoader: Carry column missing for LA1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:07:29,976 WARNING DataLoader: No data returned for ticker LA1 Comdty. Attempt 1/10
# 2024-10-22 12:07:29,977 ERROR DataLoader: Error loading data for LA1 Comdty (Attempt 1/10): No data returned for ticker LA1 Comdty.
# 2024-10-22 12:07:34,080 INFO DataLoader: Successfully loaded data for ticker LA1 Comdty with 6894 records.
# 2024-10-22 12:07:34,082 INFO DataLoader: Calculating Carry for LA1 Comdty using carry contract LA2 Comdty
# 2024-10-22 12:07:43,549 WARNING DataLoader: No data returned for ticker LA2 Comdty. Attempt 1/10
# 2024-10-22 12:07:43,550 ERROR DataLoader: Error loading data for LA2 Comdty (Attempt 1/10): No data returned for ticker LA2 Comdty.
# 2024-10-22 12:07:50,667 INFO DataLoader: Successfully loaded data for ticker LA2 Comdty with 6893 records.
# 2024-10-22 12:07:50,671 INFO DataLoader: Carry calculated and added for LA1 Comdty.
# 2024-10-22 12:07:50,686 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-base\LA1 Comdty.parquet
# Processing tickers:   4%|▍         | 4/104 [02:10<50:14, 30.15s/ticker]2024-10-22 12:07:51,693 INFO DataLoader: Carry column missing for SCO1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:07:55,349 INFO DataLoader: Successfully loaded data for ticker SCO1 Comdty with 2995 records.
# 2024-10-22 12:07:55,351 INFO DataLoader: Calculating Carry for SCO1 Comdty using carry contract SCO2 Comdty
# 2024-10-22 12:07:59,036 INFO DataLoader: Successfully loaded data for ticker SCO2 Comdty with 2996 records.
# 2024-10-22 12:07:59,040 INFO DataLoader: Carry calculated and added for SCO1 Comdty.
# 2024-10-22 12:07:59,052 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-base\SCO1 Comdty.parquet
# Processing tickers:   5%|▍         | 5/104 [02:18<36:46, 22.29s/ticker]2024-10-22 12:08:00,059 INFO DataLoader: Carry column missing for NG1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:08:08,020 INFO DataLoader: Successfully loaded data for ticker NG1 Comdty with 8689 records.
# 2024-10-22 12:08:08,022 INFO DataLoader: Calculating Carry for NG1 Comdty using carry contract NG2 Comdty
# 2024-10-22 12:08:17,088 INFO DataLoader: Successfully loaded data for ticker NG2 Comdty with 8691 records.
# 2024-10-22 12:08:17,093 INFO DataLoader: Carry calculated and added for NG1 Comdty.
# 2024-10-22 12:08:17,109 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\NG1 Comdty.parquet
# Processing tickers:   6%|▌         | 6/104 [02:36<34:03, 20.85s/ticker]2024-10-22 12:08:18,117 INFO DataLoader: Carry column missing for XB1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:08:21,869 INFO DataLoader: Successfully loaded data for ticker XB1 Comdty with 4800 records.
# 2024-10-22 12:08:21,871 INFO DataLoader: Calculating Carry for XB1 Comdty using carry contract XB2 Comdty
# 2024-10-22 12:08:30,458 INFO DataLoader: Successfully loaded data for ticker XB2 Comdty with 4800 records.
# 2024-10-22 12:08:30,462 INFO DataLoader: Carry calculated and added for XB1 Comdty.
# 2024-10-22 12:08:30,476 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\XB1 Comdty.parquet
# Processing tickers:   7%|▋         | 7/104 [02:50<29:45, 18.40s/ticker]2024-10-22 12:08:31,482 INFO DataLoader: Carry column missing for CO1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:08:41,998 WARNING DataLoader: No data returned for ticker CO1 Comdty. Attempt 1/10
# 2024-10-22 12:08:41,999 ERROR DataLoader: Error loading data for CO1 Comdty (Attempt 1/10): No data returned for ticker CO1 Comdty.
# 2024-10-22 12:08:48,193 INFO DataLoader: Successfully loaded data for ticker CO1 Comdty with 9310 records.
# 2024-10-22 12:08:48,194 INFO DataLoader: Calculating Carry for CO1 Comdty using carry contract CO2 Comdty
# 2024-10-22 12:08:54,099 WARNING DataLoader: No data returned for ticker CO2 Comdty. Attempt 1/10
# 2024-10-22 12:08:54,100 ERROR DataLoader: Error loading data for CO2 Comdty (Attempt 1/10): No data returned for ticker CO2 Comdty.
# 2024-10-22 12:08:59,553 INFO DataLoader: Successfully loaded data for ticker CO2 Comdty with 9271 records.
# 2024-10-22 12:08:59,559 INFO DataLoader: Carry calculated and added for CO1 Comdty.
# 2024-10-22 12:08:59,574 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\CO1 Comdty.parquet
# Processing tickers:   8%|▊         | 8/104 [03:19<34:53, 21.81s/ticker]2024-10-22 12:09:00,582 INFO DataLoader: Carry column missing for QS1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:09:05,382 WARNING DataLoader: No data returned for ticker QS1 Comdty. Attempt 1/10
# 2024-10-22 12:09:05,382 ERROR DataLoader: Error loading data for QS1 Comdty (Attempt 1/10): No data returned for ticker QS1 Comdty.
# 2024-10-22 12:09:11,304 INFO DataLoader: Successfully loaded data for ticker QS1 Comdty with 9042 records.
# 2024-10-22 12:09:11,306 INFO DataLoader: Calculating Carry for QS1 Comdty using carry contract QS2 Comdty
# 2024-10-22 12:09:15,186 WARNING DataLoader: No data returned for ticker QS2 Comdty. Attempt 1/10
# 2024-10-22 12:09:15,187 ERROR DataLoader: Error loading data for QS2 Comdty (Attempt 1/10): No data returned for ticker QS2 Comdty.
# 2024-10-22 12:09:23,331 INFO DataLoader: Successfully loaded data for ticker QS2 Comdty with 9042 records.
# 2024-10-22 12:09:23,336 INFO DataLoader: Carry calculated and added for QS1 Comdty.
# 2024-10-22 12:09:23,351 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\QS1 Comdty.parquet
# Processing tickers:   9%|▊         | 9/104 [03:43<35:30, 22.42s/ticker]2024-10-22 12:09:24,360 INFO DataLoader: Carry column missing for TZT2 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:09:27,067 WARNING DataLoader: No data returned for ticker TZT2 Comdty. Attempt 1/10
# 2024-10-22 12:09:27,068 ERROR DataLoader: Error loading data for TZT2 Comdty (Attempt 1/10): No data returned for ticker TZT2 Comdty.
# 2024-10-22 12:09:30,698 INFO DataLoader: Successfully loaded data for ticker TZT2 Comdty with 4947 records.
# 2024-10-22 12:09:30,700 INFO DataLoader: Calculating Carry for TZT2 Comdty using carry contract TZT2 Comdty
# 2024-10-22 12:09:35,298 INFO DataLoader: Successfully loaded data for ticker TZT2 Comdty with 4947 records.
# 2024-10-22 12:09:35,301 WARNING DataLoader: Expiration dates for TZT2 Comdty and TZT2 Comdty are the same. Skipping annualization.
# 2024-10-22 12:09:35,303 INFO DataLoader: Carry calculated and added for TZT2 Comdty.
# 2024-10-22 12:09:35,316 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\TZT2 Comdty.parquet
# Processing tickers:  10%|▉         | 10/104 [03:55<30:04, 19.20s/ticker]2024-10-22 12:09:36,324 INFO DataLoader: Carry column missing for CL1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:09:46,425 INFO DataLoader: Successfully loaded data for ticker CL1 Comdty with 10452 records.
# 2024-10-22 12:09:46,427 INFO DataLoader: Calculating Carry for CL1 Comdty using carry contract CL2 Comdty
# 2024-10-22 12:09:58,007 WARNING DataLoader: No data returned for ticker CL2 Comdty. Attempt 1/10
# 2024-10-22 12:09:58,008 ERROR DataLoader: Error loading data for CL2 Comdty (Attempt 1/10): No data returned for ticker CL2 Comdty.
# 2024-10-22 12:10:09,518 WARNING DataLoader: No data returned for ticker CL2 Comdty. Attempt 2/10
# 2024-10-22 12:10:09,519 ERROR DataLoader: Error loading data for CL2 Comdty (Attempt 2/10): No data returned for ticker CL2 Comdty.
# 2024-10-22 12:10:12,949 INFO DataLoader: Successfully loaded data for ticker CL2 Comdty with 10450 records.
# 2024-10-22 12:10:12,954 INFO DataLoader: Carry calculated and added for CL1 Comdty.
# 2024-10-22 12:10:12,970 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\CL1 Comdty.parquet
# Processing tickers:  11%|█         | 11/104 [04:32<38:30, 24.84s/ticker]2024-10-22 12:10:13,982 INFO DataLoader: Carry column missing for MO1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:10:15,845 INFO DataLoader: Successfully loaded data for ticker MO1 Comdty with 5022 records.
# 2024-10-22 12:10:15,847 INFO DataLoader: Calculating Carry for MO1 Comdty using carry contract MO2 Comdty
# 2024-10-22 12:10:18,371 INFO DataLoader: Successfully loaded data for ticker MO2 Comdty with 5004 records.
# 2024-10-22 12:10:18,375 INFO DataLoader: Carry calculated and added for MO1 Comdty.
# 2024-10-22 12:10:18,388 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\MO1 Comdty.parquet
# Processing tickers:  12%|█▏        | 12/104 [04:38<29:01, 18.93s/ticker]2024-10-22 12:10:19,399 INFO DataLoader: Carry column missing for HO1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:10:27,742 WARNING DataLoader: No data returned for ticker HO1 Comdty. Attempt 1/10
# 2024-10-22 12:10:27,743 ERROR DataLoader: Error loading data for HO1 Comdty (Attempt 1/10): No data returned for ticker HO1 Comdty.
# 2024-10-22 12:10:36,081 INFO DataLoader: Successfully loaded data for ticker HO1 Comdty with 9637 records.
# 2024-10-22 12:10:36,083 INFO DataLoader: Calculating Carry for HO1 Comdty using carry contract HO2 Comdty
# 2024-10-22 12:10:45,850 WARNING DataLoader: No data returned for ticker HO2 Comdty. Attempt 1/10
# 2024-10-22 12:10:45,850 ERROR DataLoader: Error loading data for HO2 Comdty (Attempt 1/10): No data returned for ticker HO2 Comdty.
# 2024-10-22 12:10:48,563 INFO DataLoader: Successfully loaded data for ticker HO2 Comdty with 9637 records.
# 2024-10-22 12:10:48,568 INFO DataLoader: Carry calculated and added for HO1 Comdty.
# 2024-10-22 12:10:48,585 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-enrgy\HO1 Comdty.parquet
# Processing tickers:  12%|█▎        | 13/104 [05:08<33:53, 22.35s/ticker]2024-10-22 12:10:49,598 INFO DataLoader: Carry column missing for GC1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:10:55,396 INFO DataLoader: Successfully loaded data for ticker GC1 Comdty with 11279 records.
# 2024-10-22 12:10:55,398 INFO DataLoader: Calculating Carry for GC1 Comdty using carry contract GC2 Comdty
# 2024-10-22 12:10:58,812 WARNING DataLoader: No data returned for ticker GC2 Comdty. Attempt 1/10
# 2024-10-22 12:10:58,812 ERROR DataLoader: Error loading data for GC2 Comdty (Attempt 1/10): No data returned for ticker GC2 Comdty.
# 2024-10-22 12:11:03,399 INFO DataLoader: Successfully loaded data for ticker GC2 Comdty with 11277 records.
# 2024-10-22 12:11:03,405 INFO DataLoader: Carry calculated and added for GC1 Comdty.
# 2024-10-22 12:11:03,421 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-prec\GC1 Comdty.parquet
# Processing tickers:  13%|█▎        | 14/104 [05:23<30:07, 20.08s/ticker]2024-10-22 12:11:04,435 INFO DataLoader: Carry column missing for PL1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:11:08,999 WARNING DataLoader: No data returned for ticker PL1 Comdty. Attempt 1/10
# 2024-10-22 12:11:09,000 ERROR DataLoader: Error loading data for PL1 Comdty (Attempt 1/10): No data returned for ticker PL1 Comdty.
# 2024-10-22 12:11:15,878 INFO DataLoader: Successfully loaded data for ticker PL1 Comdty with 9701 records.
# 2024-10-22 12:11:15,880 INFO DataLoader: Calculating Carry for PL1 Comdty using carry contract PL2 Comdty
# 2024-10-22 12:11:21,701 INFO DataLoader: Successfully loaded data for ticker PL2 Comdty with 9631 records.
# 2024-10-22 12:11:21,707 INFO DataLoader: Carry calculated and added for PL1 Comdty.
# 2024-10-22 12:11:21,723 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-prec\PL1 Comdty.parquet
# Processing tickers:  14%|█▍        | 15/104 [05:41<28:59, 19.54s/ticker]2024-10-22 12:11:22,737 INFO DataLoader: Carry column missing for SI1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:11:27,315 INFO DataLoader: Successfully loaded data for ticker SI1 Comdty with 11281 records.
# 2024-10-22 12:11:27,317 INFO DataLoader: Calculating Carry for SI1 Comdty using carry contract SI2 Comdty
# 2024-10-22 12:11:32,323 INFO DataLoader: Successfully loaded data for ticker SI2 Comdty with 11280 records.
# 2024-10-22 12:11:32,328 INFO DataLoader: Carry calculated and added for SI1 Comdty.
# 2024-10-22 12:11:32,344 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-prec\SI1 Comdty.parquet
# Processing tickers:  15%|█▌        | 16/104 [05:52<24:43, 16.86s/ticker]2024-10-22 12:11:33,356 INFO DataLoader: Carry column missing for RS1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:11:38,971 INFO DataLoader: Successfully loaded data for ticker RS1 Comdty with 10741 records.
# 2024-10-22 12:11:38,973 INFO DataLoader: Calculating Carry for RS1 Comdty using carry contract RS2 Comdty
# 2024-10-22 12:11:44,673 INFO DataLoader: Successfully loaded data for ticker RS2 Comdty with 10643 records.
# 2024-10-22 12:11:44,678 INFO DataLoader: Carry calculated and added for RS1 Comdty.
# 2024-10-22 12:11:44,694 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\RS1 Comdty.parquet
# Processing tickers:  16%|█▋        | 17/104 [06:04<22:28, 15.50s/ticker]2024-10-22 12:11:45,709 INFO DataLoader: Carry column missing for CA1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:11:49,240 INFO DataLoader: Successfully loaded data for ticker CA1 Comdty with 6611 records.
# 2024-10-22 12:11:49,242 INFO DataLoader: Calculating Carry for CA1 Comdty using carry contract CA2 Comdty
# 2024-10-22 12:11:52,292 INFO DataLoader: Successfully loaded data for ticker CA2 Comdty with 6609 records.
# 2024-10-22 12:11:52,296 INFO DataLoader: Carry calculated and added for CA1 Comdty.
# 2024-10-22 12:11:52,310 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\CA1 Comdty.parquet
# Processing tickers:  17%|█▋        | 18/104 [06:12<18:49, 13.13s/ticker]2024-10-22 12:11:53,323 INFO DataLoader: Carry column missing for SB1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:11:58,629 INFO DataLoader: Successfully loaded data for ticker SB1 Comdty with 11284 records.
# 2024-10-22 12:11:58,631 INFO DataLoader: Calculating Carry for SB1 Comdty using carry contract SB2 Comdty
# 2024-10-22 12:12:04,602 INFO DataLoader: Successfully loaded data for ticker SB2 Comdty with 11278 records.
# 2024-10-22 12:12:04,608 INFO DataLoader: Carry calculated and added for SB1 Comdty.
# 2024-10-22 12:12:04,623 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\SB1 Comdty.parquet
# Processing tickers:  18%|█▊        | 19/104 [06:24<18:15, 12.89s/ticker]2024-10-22 12:12:05,636 INFO DataLoader: Carry column missing for RR1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:12:10,943 INFO DataLoader: Successfully loaded data for ticker RR1 Comdty with 9008 records.
# 2024-10-22 12:12:10,945 INFO DataLoader: Calculating Carry for RR1 Comdty using carry contract RR2 Comdty
# 2024-10-22 12:12:19,613 INFO DataLoader: Successfully loaded data for ticker RR2 Comdty with 9006 records.
# 2024-10-22 12:12:19,617 INFO DataLoader: Carry calculated and added for RR1 Comdty.
# 2024-10-22 12:12:19,632 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\RR1 Comdty.parquet
# Processing tickers:  19%|█▉        | 20/104 [06:39<18:55, 13.52s/ticker]2024-10-22 12:12:20,645 INFO DataLoader: Carry column missing for KC1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:12:27,062 INFO DataLoader: Successfully loaded data for ticker KC1 Comdty with 11273 records.
# 2024-10-22 12:12:27,064 INFO DataLoader: Calculating Carry for KC1 Comdty using carry contract KC2 Comdty
# 2024-10-22 12:12:33,703 INFO DataLoader: Successfully loaded data for ticker KC2 Comdty with 11286 records.
# 2024-10-22 12:12:33,709 INFO DataLoader: Carry calculated and added for KC1 Comdty.
# 2024-10-22 12:12:33,724 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\KC1 Comdty.parquet
# Processing tickers:  20%|██        | 21/104 [06:53<18:56, 13.69s/ticker]2024-10-22 12:12:34,738 INFO DataLoader: Carry column missing for BO1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:12:41,532 INFO DataLoader: Successfully loaded data for ticker BO1 Comdty with 11322 records.
# 2024-10-22 12:12:41,534 INFO DataLoader: Calculating Carry for BO1 Comdty using carry contract BO2 Comdty
# 2024-10-22 12:12:51,060 INFO DataLoader: Successfully loaded data for ticker BO2 Comdty with 11319 records.
# 2024-10-22 12:12:51,065 INFO DataLoader: Carry calculated and added for BO1 Comdty.
# 2024-10-22 12:12:51,081 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\BO1 Comdty.parquet
# Processing tickers:  21%|██        | 22/104 [07:10<20:13, 14.79s/ticker]2024-10-22 12:12:52,093 INFO DataLoader: Carry column missing for FC1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:13:01,467 INFO DataLoader: Successfully loaded data for ticker FC1 Comdty with 11332 records.
# 2024-10-22 12:13:01,469 INFO DataLoader: Calculating Carry for FC1 Comdty using carry contract FC2 Comdty
# 2024-10-22 12:13:10,808 INFO DataLoader: Successfully loaded data for ticker FC2 Comdty with 11331 records.
# 2024-10-22 12:13:10,813 INFO DataLoader: Carry calculated and added for FC1 Comdty.
# 2024-10-22 12:13:10,829 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\FC1 Comdty.parquet
# Processing tickers:  22%|██▏       | 23/104 [07:30<21:58, 16.28s/ticker]2024-10-22 12:13:11,843 INFO DataLoader: Carry column missing for C 1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:13:19,291 INFO DataLoader: Successfully loaded data for ticker C 1 Comdty with 11322 records.
# 2024-10-22 12:13:19,294 INFO DataLoader: Calculating Carry for C 1 Comdty using carry contract C 2 Comdty
# 2024-10-22 12:13:25,367 INFO DataLoader: Successfully loaded data for ticker C 2 Comdty with 11320 records.
# 2024-10-22 12:13:25,372 INFO DataLoader: Carry calculated and added for C 1 Comdty.
# 2024-10-22 12:13:25,389 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\C 1 Comdty.parquet
# Processing tickers:  23%|██▎       | 24/104 [07:45<21:01, 15.76s/ticker]2024-10-22 12:13:26,408 INFO DataLoader: Carry column missing for W 1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:13:33,329 INFO DataLoader: Successfully loaded data for ticker W 1 Comdty with 11311 records.
# 2024-10-22 12:13:33,332 INFO DataLoader: Calculating Carry for W 1 Comdty using carry contract W 2 Comdty
# 2024-10-22 12:13:39,313 INFO DataLoader: Successfully loaded data for ticker W 2 Comdty with 11310 records.
# 2024-10-22 12:13:39,319 INFO DataLoader: Carry calculated and added for W 1 Comdty.
# 2024-10-22 12:13:39,334 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\W 1 Comdty.parquet
# Processing tickers:  24%|██▍       | 25/104 [07:59<20:02, 15.22s/ticker]2024-10-22 12:13:40,358 INFO DataLoader: Carry column missing for SM1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:13:50,871 WARNING DataLoader: No data returned for ticker SM1 Comdty. Attempt 1/10
# 2024-10-22 12:13:50,872 ERROR DataLoader: Error loading data for SM1 Comdty (Attempt 1/10): No data returned for ticker SM1 Comdty.
# 2024-10-22 12:13:52,962 INFO DataLoader: Successfully loaded data for ticker SM1 Comdty with 11324 records.
# 2024-10-22 12:13:52,964 INFO DataLoader: Calculating Carry for SM1 Comdty using carry contract SM2 Comdty
# 2024-10-22 12:13:59,253 WARNING DataLoader: No data returned for ticker SM2 Comdty. Attempt 1/10
# 2024-10-22 12:13:59,254 ERROR DataLoader: Error loading data for SM2 Comdty (Attempt 1/10): No data returned for ticker SM2 Comdty.
# 2024-10-22 12:14:00,615 INFO DataLoader: Successfully loaded data for ticker SM2 Comdty with 11320 records.
# 2024-10-22 12:14:00,621 INFO DataLoader: Carry calculated and added for SM1 Comdty.
# 2024-10-22 12:14:00,638 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\SM1 Comdty.parquet
# Processing tickers:  25%|██▌       | 26/104 [08:20<22:09, 17.04s/ticker]2024-10-22 12:14:01,653 INFO DataLoader: Carry column missing for YW1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:14:06,849 INFO DataLoader: Successfully loaded data for ticker YW1 Comdty with 6981 records.
# 2024-10-22 12:14:06,851 INFO DataLoader: Calculating Carry for YW1 Comdty using carry contract YW2 Comdty
# 2024-10-22 12:14:10,590 INFO DataLoader: Successfully loaded data for ticker YW2 Comdty with 6916 records.
# 2024-10-22 12:14:10,595 INFO DataLoader: Carry calculated and added for YW1 Comdty.
# 2024-10-22 12:14:10,609 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\YW1 Comdty.parquet
# Processing tickers:  26%|██▌       | 27/104 [08:30<19:08, 14.92s/ticker]2024-10-22 12:14:11,623 INFO DataLoader: Carry column missing for S 1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:14:12,450 WARNING DataLoader: No data returned for ticker S 1 Comdty. Attempt 1/10
# 2024-10-22 12:14:12,451 ERROR DataLoader: Error loading data for S 1 Comdty (Attempt 1/10): No data returned for ticker S 1 Comdty.
# 2024-10-22 12:14:20,235 INFO DataLoader: Successfully loaded data for ticker S 1 Comdty with 11323 records.
# 2024-10-22 12:14:20,237 INFO DataLoader: Calculating Carry for S 1 Comdty using carry contract S 2 Comdty
# 2024-10-22 12:14:21,713 WARNING DataLoader: No data returned for ticker S 2 Comdty. Attempt 1/10
# 2024-10-22 12:14:21,714 ERROR DataLoader: Error loading data for S 2 Comdty (Attempt 1/10): No data returned for ticker S 2 Comdty.
# 2024-10-22 12:14:31,408 INFO DataLoader: Successfully loaded data for ticker S 2 Comdty with 11319 records.
# 2024-10-22 12:14:31,413 INFO DataLoader: Carry calculated and added for S 1 Comdty.
# 2024-10-22 12:14:31,429 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\S 1 Comdty.parquet
# Processing tickers:  27%|██▋       | 28/104 [08:51<21:08, 16.69s/ticker]2024-10-22 12:14:32,443 INFO DataLoader: Skipping RS1 Comdty as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:14:32,448 INFO DataLoader: Skipping QC1 Comdty as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:14:32,453 INFO DataLoader: Carry column missing for QW1 Comdty. Proceeding with carry calculation.
# 2024-10-22 12:14:34,314 WARNING DataLoader: No data returned for ticker QW1 Comdty. Attempt 1/10
# 2024-10-22 12:14:34,315 ERROR DataLoader: Error loading data for QW1 Comdty (Attempt 1/10): No data returned for ticker QW1 Comdty.
# 2024-10-22 12:14:39,119 INFO DataLoader: Successfully loaded data for ticker QW1 Comdty with 9107 records.
# 2024-10-22 12:14:39,121 INFO DataLoader: Calculating Carry for QW1 Comdty using carry contract QW2 Comdty
# 2024-10-22 12:14:39,365 WARNING DataLoader: Could not retrieve expiration dates for QW1 Comdty or QW2 Comdty. Skipping Carry calculation.
# 2024-10-22 12:14:39,378 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\comm-soft\QW1 Comdty.parquet
# Processing tickers:  30%|██▉       | 31/104 [08:59<10:41,  8.79s/ticker]2024-10-22 12:14:40,392 INFO DataLoader: Carry column missing for BTC1 Curncy. Proceeding with carry calculation.
# 2024-10-22 12:14:42,165 INFO DataLoader: Successfully loaded data for ticker BTC1 Curncy with 1725 records.
# 2024-10-22 12:14:42,167 INFO DataLoader: Calculating Carry for BTC1 Curncy using carry contract BTC2 Curncy
# 2024-10-22 12:14:44,373 INFO DataLoader: Successfully loaded data for ticker BTC2 Curncy with 1725 records.
# 2024-10-22 12:14:44,377 INFO DataLoader: Carry calculated and added for BTC1 Curncy.
# 2024-10-22 12:14:44,394 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\crypto\BTC1 Curncy.parquet
# Processing tickers:  31%|███       | 32/104 [09:04<09:35,  7.99s/ticker]2024-10-22 12:14:45,408 INFO DataLoader: Carry column missing for DCR1 Curncy. Proceeding with carry calculation.
# 2024-10-22 12:14:46,489 INFO DataLoader: Successfully loaded data for ticker DCR1 Curncy with 935 records.
# 2024-10-22 12:14:46,491 INFO DataLoader: Calculating Carry for DCR1 Curncy using carry contract DCR2 Curncy
# 2024-10-22 12:14:48,062 INFO DataLoader: Successfully loaded data for ticker DCR2 Curncy with 934 records.
# 2024-10-22 12:14:48,066 INFO DataLoader: Carry calculated and added for DCR1 Curncy.
# 2024-10-22 12:14:48,074 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\crypto\DCR1 Curncy.parquet
# Processing tickers:  32%|███▏      | 33/104 [09:07<08:16,  6.99s/ticker]2024-10-22 12:14:49,082 INFO DataLoader: Carry column missing for XP1 Index. Proceeding with carry calculation.
# 2024-10-22 12:14:51,478 INFO DataLoader: Successfully loaded data for ticker XP1 Index with 6297 records.
# 2024-10-22 12:14:51,480 INFO DataLoader: Calculating Carry for XP1 Index using carry contract XP2 Index
# 2024-10-22 12:14:54,603 INFO DataLoader: Successfully loaded data for ticker XP2 Index with 6270 records.
# 2024-10-22 12:14:54,607 INFO DataLoader: Carry calculated and added for XP1 Index.
# 2024-10-22 12:14:54,622 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-as\XP1 Index.parquet
# Processing tickers:  33%|███▎      | 34/104 [09:14<08:01,  6.88s/ticker]2024-10-22 12:14:55,635 INFO DataLoader: Carry column missing for NK1 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:01,821 INFO DataLoader: Successfully loaded data for ticker NK1 Index with 8868 records.
# 2024-10-22 12:15:01,823 INFO DataLoader: Calculating Carry for NK1 Index using carry contract NK2 Index
# 2024-10-22 12:15:09,105 INFO DataLoader: Successfully loaded data for ticker NK2 Index with 8514 records.
# 2024-10-22 12:15:09,110 INFO DataLoader: Carry calculated and added for NK1 Index.
# 2024-10-22 12:15:09,125 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-as\NK1 Index.parquet
# Processing tickers:  34%|███▎      | 35/104 [09:28<10:12,  8.88s/ticker]2024-10-22 12:15:10,139 INFO DataLoader: Carry column missing for TP1 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:15,626 INFO DataLoader: Successfully loaded data for ticker TP1 Index with 8458 records.
# 2024-10-22 12:15:15,628 INFO DataLoader: Calculating Carry for TP1 Index using carry contract TP2 Index
# 2024-10-22 12:15:20,116 INFO DataLoader: Successfully loaded data for ticker TP2 Index with 7434 records.
# 2024-10-22 12:15:20,122 INFO DataLoader: Carry calculated and added for TP1 Index.
# 2024-10-22 12:15:20,139 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-as\TP1 Index.parquet
# Processing tickers:  35%|███▍      | 36/104 [09:39<10:43,  9.46s/ticker]2024-10-22 12:15:21,152 INFO DataLoader: Carry column missing for ASD3 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:21,960 INFO DataLoader: Successfully loaded data for ticker ASD3 Index with 2251 records.
# 2024-10-22 12:15:21,963 INFO DataLoader: Calculating Carry for ASD3 Index using carry contract ASD2 Index
# 2024-10-22 12:15:23,364 INFO DataLoader: Successfully loaded data for ticker ASD2 Index with 2251 records.
# 2024-10-22 12:15:23,367 INFO DataLoader: Carry calculated and added for ASD3 Index.
# 2024-10-22 12:15:23,380 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-divf\ASD3 Index.parquet
# Processing tickers:  36%|███▌      | 37/104 [09:43<08:37,  7.72s/ticker]2024-10-22 12:15:24,391 INFO DataLoader: Carry column missing for DBE3 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:25,324 INFO DataLoader: Successfully loaded data for ticker DBE3 Index with 3225 records.
# 2024-10-22 12:15:25,326 INFO DataLoader: Calculating Carry for DBE3 Index using carry contract DBE2 Index
# 2024-10-22 12:15:26,704 INFO DataLoader: Successfully loaded data for ticker DBE2 Index with 3226 records.
# 2024-10-22 12:15:26,708 INFO DataLoader: Carry calculated and added for DBE3 Index.
# 2024-10-22 12:15:26,722 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-divf\DBE3 Index.parquet
# Processing tickers:  37%|███▋      | 38/104 [09:46<07:06,  6.47s/ticker]2024-10-22 12:15:27,734 INFO DataLoader: Carry column missing for DED3 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:29,037 INFO DataLoader: Successfully loaded data for ticker DED3 Index with 4164 records.
# 2024-10-22 12:15:29,038 INFO DataLoader: Calculating Carry for DED3 Index using carry contract DED2 Index
# 2024-10-22 12:15:31,215 INFO DataLoader: Successfully loaded data for ticker DED2 Index with 4165 records.
# 2024-10-22 12:15:31,220 INFO DataLoader: Carry calculated and added for DED3 Index.
# 2024-10-22 12:15:31,234 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-divf\DED3 Index.parquet
# Processing tickers:  38%|███▊      | 39/104 [09:50<06:23,  5.90s/ticker]2024-10-22 12:15:32,247 INFO DataLoader: Carry column missing for MND3 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:33,420 INFO DataLoader: Successfully loaded data for ticker MND3 Index with 3718 records.
# 2024-10-22 12:15:33,422 INFO DataLoader: Calculating Carry for MND3 Index using carry contract MND2 Index
# 2024-10-22 12:15:35,497 INFO DataLoader: Successfully loaded data for ticker MND2 Index with 3719 records.
# 2024-10-22 12:15:35,501 INFO DataLoader: Carry calculated and added for MND3 Index.
# 2024-10-22 12:15:35,514 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-divf\MND3 Index.parquet
# Processing tickers:  38%|███▊      | 40/104 [09:55<05:47,  5.43s/ticker]2024-10-22 12:15:36,527 INFO DataLoader: Carry column missing for XU1 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:44,432 INFO DataLoader: Successfully loaded data for ticker XU1 Index with 4531 records.
# 2024-10-22 12:15:44,434 INFO DataLoader: Calculating Carry for XU1 Index using carry contract XU2 Index
# 2024-10-22 12:15:51,639 INFO DataLoader: Successfully loaded data for ticker XU2 Index with 4526 records.
# 2024-10-22 12:15:51,643 INFO DataLoader: Carry calculated and added for XU1 Index.
# 2024-10-22 12:15:51,661 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-em\XU1 Index.parquet
# Processing tickers:  39%|███▉      | 41/104 [10:11<09:01,  8.59s/ticker]2024-10-22 12:15:52,674 INFO DataLoader: Carry column missing for ZVL1 Index. Proceeding with carry calculation.
# 2024-10-22 12:15:54,371 INFO DataLoader: Successfully loaded data for ticker ZVL1 Index with 2884 records.
# 2024-10-22 12:15:54,373 INFO DataLoader: Calculating Carry for ZVL1 Index using carry contract ZVL2 Index
# 2024-10-22 12:15:56,629 INFO DataLoader: Successfully loaded data for ticker ZVL2 Index with 2887 records.
# 2024-10-22 12:15:56,632 INFO DataLoader: Carry calculated and added for ZVL1 Index.
# 2024-10-22 12:15:56,644 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-em\ZVL1 Index.parquet
# Processing tickers:  40%|████      | 42/104 [10:16<07:46,  7.52s/ticker]2024-10-22 12:15:57,655 INFO DataLoader: Carry column missing for QZ1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:08,167 WARNING DataLoader: No data returned for ticker QZ1 Index. Attempt 1/10
# 2024-10-22 12:16:08,168 ERROR DataLoader: Error loading data for QZ1 Index (Attempt 1/10): No data returned for ticker QZ1 Index.
# 2024-10-22 12:16:09,788 INFO DataLoader: Successfully loaded data for ticker QZ1 Index with 6724 records.
# 2024-10-22 12:16:09,790 INFO DataLoader: Calculating Carry for QZ1 Index using carry contract QZ2 Index
# 2024-10-22 12:16:17,204 WARNING DataLoader: No data returned for ticker QZ2 Index. Attempt 1/10
# 2024-10-22 12:16:17,205 ERROR DataLoader: Error loading data for QZ2 Index (Attempt 1/10): No data returned for ticker QZ2 Index.
# 2024-10-22 12:16:21,667 INFO DataLoader: Successfully loaded data for ticker QZ2 Index with 6647 records.
# 2024-10-22 12:16:21,672 INFO DataLoader: Carry calculated and added for QZ1 Index.
# 2024-10-22 12:16:21,687 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-em\QZ1 Index.parquet
# Processing tickers:  41%|████▏     | 43/104 [10:41<12:56, 12.73s/ticker]2024-10-22 12:16:22,699 INFO DataLoader: Skipping HC1 Index as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:16:22,704 INFO DataLoader: Carry column missing for KM1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:26,475 INFO DataLoader: Successfully loaded data for ticker KM1 Index with 7147 records.
# 2024-10-22 12:16:26,477 INFO DataLoader: Calculating Carry for KM1 Index using carry contract KM2 Index
# 2024-10-22 12:16:28,637 WARNING DataLoader: No data returned for ticker KM2 Index. Attempt 1/10
# 2024-10-22 12:16:28,638 ERROR DataLoader: Error loading data for KM2 Index (Attempt 1/10): No data returned for ticker KM2 Index.
# 2024-10-22 12:16:32,061 INFO DataLoader: Successfully loaded data for ticker KM2 Index with 7033 records.
# 2024-10-22 12:16:32,066 INFO DataLoader: Carry calculated and added for KM1 Index.
# 2024-10-22 12:16:32,082 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-em\KM1 Index.parquet
# Processing tickers:  43%|████▎     | 45/104 [10:51<09:06,  9.27s/ticker]2024-10-22 12:16:33,096 INFO DataLoader: Skipping XB1 Index as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:16:33,100 INFO DataLoader: Carry column missing for MES1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:35,127 INFO DataLoader: Successfully loaded data for ticker MES1 Index with 3900 records.
# 2024-10-22 12:16:35,129 INFO DataLoader: Calculating Carry for MES1 Index using carry contract MES2 Index
# 2024-10-22 12:16:37,771 INFO DataLoader: Successfully loaded data for ticker MES2 Index with 3899 records.
# 2024-10-22 12:16:37,775 INFO DataLoader: Carry calculated and added for MES1 Index.
# 2024-10-22 12:16:37,799 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-em\MES1 Index.parquet
# Processing tickers:  45%|████▌     | 47/104 [10:57<06:23,  6.73s/ticker]2024-10-22 12:16:38,807 INFO DataLoader: Skipping XB1 Index as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:16:38,813 INFO DataLoader: Carry column missing for VG1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:42,859 INFO DataLoader: Successfully loaded data for ticker VG1 Index with 6712 records.
# 2024-10-22 12:16:42,861 INFO DataLoader: Calculating Carry for VG1 Index using carry contract VG2 Index
# 2024-10-22 12:16:47,359 INFO DataLoader: Successfully loaded data for ticker VG2 Index with 6714 records.
# 2024-10-22 12:16:47,364 INFO DataLoader: Carry calculated and added for VG1 Index.
# 2024-10-22 12:16:47,379 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\VG1 Index.parquet
# Processing tickers:  47%|████▋     | 49/104 [11:07<05:31,  6.03s/ticker]2024-10-22 12:16:48,393 INFO DataLoader: Carry column missing for CA1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:51,296 INFO DataLoader: Successfully loaded data for ticker CA1 Index with 6017 records.
# 2024-10-22 12:16:51,298 INFO DataLoader: Calculating Carry for CA1 Index using carry contract CA2 Index
# 2024-10-22 12:16:54,440 INFO DataLoader: Successfully loaded data for ticker CA2 Index with 6014 records.
# 2024-10-22 12:16:54,446 INFO DataLoader: Carry calculated and added for CA1 Index.
# 2024-10-22 12:16:54,461 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\CA1 Index.parquet
# Processing tickers:  48%|████▊     | 50/104 [11:14<05:37,  6.24s/ticker]2024-10-22 12:16:55,473 INFO DataLoader: Carry column missing for GX1 Index. Proceeding with carry calculation.
# 2024-10-22 12:16:59,347 INFO DataLoader: Successfully loaded data for ticker GX1 Index with 8612 records.
# 2024-10-22 12:16:59,349 INFO DataLoader: Calculating Carry for GX1 Index using carry contract GX2 Index
# 2024-10-22 12:17:03,678 INFO DataLoader: Successfully loaded data for ticker GX2 Index with 8612 records.
# 2024-10-22 12:17:03,682 INFO DataLoader: Carry calculated and added for GX1 Index.
# 2024-10-22 12:17:03,700 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\GX1 Index.parquet
# Processing tickers:  49%|████▉     | 51/104 [11:23<06:06,  6.92s/ticker]2024-10-22 12:17:04,713 INFO DataLoader: Carry column missing for CF1 Index. Proceeding with carry calculation.
# 2024-10-22 12:17:15,227 WARNING DataLoader: No data returned for ticker CF1 Index. Attempt 1/10
# 2024-10-22 12:17:15,228 ERROR DataLoader: Error loading data for CF1 Index (Attempt 1/10): No data returned for ticker CF1 Index.
# 2024-10-22 12:17:20,327 INFO DataLoader: Successfully loaded data for ticker CF1 Index with 9130 records.
# 2024-10-22 12:17:20,329 INFO DataLoader: Calculating Carry for CF1 Index using carry contract CF2 Index
# 2024-10-22 12:17:27,458 WARNING DataLoader: No data returned for ticker CF2 Index. Attempt 1/10
# 2024-10-22 12:17:27,459 ERROR DataLoader: Error loading data for CF2 Index (Attempt 1/10): No data returned for ticker CF2 Index.
# 2024-10-22 12:17:31,551 INFO DataLoader: Successfully loaded data for ticker CF2 Index with 9087 records.
# 2024-10-22 12:17:31,556 INFO DataLoader: Carry calculated and added for CF1 Index.
# 2024-10-22 12:17:31,572 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\CF1 Index.parquet
# Processing tickers:  50%|█████     | 52/104 [11:51<10:26, 12.05s/ticker]2024-10-22 12:17:32,584 INFO DataLoader: Carry column missing for IB1 Index. Proceeding with carry calculation.
# 2024-10-22 12:17:38,970 WARNING DataLoader: No data returned for ticker IB1 Index. Attempt 1/10
# 2024-10-22 12:17:38,971 ERROR DataLoader: Error loading data for IB1 Index (Attempt 1/10): No data returned for ticker IB1 Index.
# 2024-10-22 12:17:41,637 INFO DataLoader: Successfully loaded data for ticker IB1 Index with 8172 records.
# 2024-10-22 12:17:41,639 INFO DataLoader: Calculating Carry for IB1 Index using carry contract IB2 Index
# 2024-10-22 12:17:51,143 WARNING DataLoader: No data returned for ticker IB2 Index. Attempt 1/10
# 2024-10-22 12:17:51,144 ERROR DataLoader: Error loading data for IB2 Index (Attempt 1/10): No data returned for ticker IB2 Index.
# 2024-10-22 12:17:52,540 INFO DataLoader: Successfully loaded data for ticker IB2 Index with 8066 records.
# 2024-10-22 12:17:52,545 INFO DataLoader: Carry calculated and added for IB1 Index.
# 2024-10-22 12:17:52,560 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\IB1 Index.parquet
# Processing tickers:  51%|█████     | 53/104 [12:12<12:12, 14.36s/ticker]2024-10-22 12:17:53,573 INFO DataLoader: Carry column missing for ST1 Index. Proceeding with carry calculation.
# 2024-10-22 12:17:56,983 INFO DataLoader: Successfully loaded data for ticker ST1 Index with 5236 records.
# 2024-10-22 12:17:56,985 INFO DataLoader: Calculating Carry for ST1 Index using carry contract ST2 Index
# 2024-10-22 12:18:00,894 INFO DataLoader: Successfully loaded data for ticker ST2 Index with 5227 records.
# 2024-10-22 12:18:00,899 INFO DataLoader: Carry calculated and added for ST1 Index.
# 2024-10-22 12:18:00,914 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\ST1 Index.parquet
# Processing tickers:  52%|█████▏    | 54/104 [12:20<10:37, 12.74s/ticker]2024-10-22 12:18:01,927 INFO DataLoader: Carry column missing for QC1 Index. Proceeding with carry calculation.
# 2024-10-22 12:18:07,237 INFO DataLoader: Successfully loaded data for ticker QC1 Index with 4955 records.
# 2024-10-22 12:18:07,240 INFO DataLoader: Calculating Carry for QC1 Index using carry contract QC2 Index
# 2024-10-22 12:18:12,245 INFO DataLoader: Successfully loaded data for ticker QC2 Index with 4941 records.
# 2024-10-22 12:18:12,250 INFO DataLoader: Carry calculated and added for QC1 Index.
# 2024-10-22 12:18:12,265 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\QC1 Index.parquet
# Processing tickers:  53%|█████▎    | 55/104 [12:32<10:05, 12.35s/ticker]2024-10-22 12:18:13,278 INFO DataLoader: Carry column missing for SM1 Index. Proceeding with carry calculation.
# 2024-10-22 12:18:17,525 INFO DataLoader: Successfully loaded data for ticker SM1 Index with 7413 records.
# 2024-10-22 12:18:17,528 INFO DataLoader: Calculating Carry for SM1 Index using carry contract SM2 Index
# 2024-10-22 12:18:21,272 INFO DataLoader: Successfully loaded data for ticker SM2 Index with 6678 records.
# 2024-10-22 12:18:21,277 INFO DataLoader: Carry calculated and added for SM1 Index.
# 2024-10-22 12:18:21,291 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\SM1 Index.parquet
# Processing tickers:  54%|█████▍    | 56/104 [12:41<09:07, 11.41s/ticker]2024-10-22 12:18:22,304 INFO DataLoader: Carry column missing for Z 1 Index. Proceeding with carry calculation.
# 2024-10-22 12:18:27,150 INFO DataLoader: Successfully loaded data for ticker Z 1 Index with 9360 records.
# 2024-10-22 12:18:27,152 INFO DataLoader: Calculating Carry for Z 1 Index using carry contract Z 2 Index
# 2024-10-22 12:18:30,740 INFO DataLoader: Successfully loaded data for ticker Z 2 Index with 9265 records.
# 2024-10-22 12:18:30,745 INFO DataLoader: Carry calculated and added for Z 1 Index.
# 2024-10-22 12:18:30,760 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-eu\Z 1 Index.parquet
# Processing tickers:  55%|█████▍    | 57/104 [12:50<08:29, 10.85s/ticker]2024-10-22 12:18:31,773 INFO DataLoader: Skipping NQ1 Index as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:18:31,778 INFO DataLoader: Skipping ES1 Index as it was already updated within the last day and has a Carry column.
# 2024-10-22 12:18:31,783 INFO DataLoader: Carry column missing for DM1 Index. Proceeding with carry calculation.
# 2024-10-22 12:18:34,590 INFO DataLoader: Successfully loaded data for ticker DM1 Index with 5698 records.
# 2024-10-22 12:18:34,592 INFO DataLoader: Calculating Carry for DM1 Index using carry contract DM2 Index
# 2024-10-22 12:18:37,758 INFO DataLoader: Successfully loaded data for ticker DM2 Index with 5669 records.
# 2024-10-22 12:18:37,763 INFO DataLoader: Carry calculated and added for DM1 Index.
# 2024-10-22 12:18:37,776 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\eq-us\DM1 Index.parquet
# ...
# 2024-10-22 12:21:17,872 INFO DataLoader: Calculating Carry for DX1 Curncy using carry contract DX2 Curncy
# 2024-10-22 12:21:22,712 INFO DataLoader: Successfully loaded data for ticker DX2 Curncy with 9738 records.
# 2024-10-22 12:21:22,717 INFO DataLoader: Carry calculated and added for DX1 Curncy.
# 2024-10-22 12:21:22,733 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\DX1 Curncy.parquet
# Processing tickers:  77%|███████▋  | 80/104 [15:42<03:42,  9.25s/ticker]2024-10-22 12:21:27,823 INFO DataLoader: Successfully loaded data for ticker JY1 Curncy with 9770 records.
# 2024-10-22 12:21:27,825 INFO DataLoader: Calculating Carry for JY1 Curncy using carry contract JY2 Curncy
# 2024-10-22 12:21:32,758 INFO DataLoader: Successfully loaded data for ticker JY2 Curncy with 9677 records.
# 2024-10-22 12:21:32,764 INFO DataLoader: Carry calculated and added for JY1 Curncy.
# 2024-10-22 12:21:32,780 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\JY1 Curncy.parquet
# Processing tickers:  78%|███████▊  | 81/104 [15:52<03:38,  9.49s/ticker]2024-10-22 12:21:39,633 INFO DataLoader: Successfully loaded data for ticker BP1 Curncy with 9767 records.
# 2024-10-22 12:21:39,635 INFO DataLoader: Calculating Carry for BP1 Curncy using carry contract BP2 Curncy
# 2024-10-22 12:21:43,844 INFO DataLoader: Successfully loaded data for ticker BP2 Curncy with 9702 records.
# 2024-10-22 12:21:43,849 INFO DataLoader: Carry calculated and added for BP1 Curncy.
# 2024-10-22 12:21:43,865 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\BP1 Curncy.parquet
# Processing tickers:  79%|███████▉  | 82/104 [16:03<03:39,  9.97s/ticker]2024-10-22 12:21:47,513 INFO DataLoader: Successfully loaded data for ticker EC1 Curncy with 6709 records.
# 2024-10-22 12:21:47,515 INFO DataLoader: Calculating Carry for EC1 Curncy using carry contract EC2 Curncy
# 2024-10-22 12:21:50,353 INFO DataLoader: Successfully loaded data for ticker EC2 Curncy with 6697 records.
# 2024-10-22 12:21:50,358 INFO DataLoader: Carry calculated and added for EC1 Curncy.
# 2024-10-22 12:21:50,372 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\EC1 Curncy.parquet
# Processing tickers:  80%|███████▉  | 83/104 [16:10<03:07,  8.93s/ticker]2024-10-22 12:21:57,248 INFO DataLoader: Successfully loaded data for ticker CD1 Curncy with 9797 records.
# 2024-10-22 12:21:57,250 INFO DataLoader: Calculating Carry for CD1 Curncy using carry contract CD2 Curncy
# 2024-10-22 12:22:03,048 INFO DataLoader: Successfully loaded data for ticker CD2 Curncy with 9717 records.
# 2024-10-22 12:22:03,053 INFO DataLoader: Carry calculated and added for CD1 Curncy.
# 2024-10-22 12:22:03,070 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\CD1 Curncy.parquet
# Processing tickers:  81%|████████  | 84/104 [16:22<03:21, 10.06s/ticker]2024-10-22 12:22:07,918 INFO DataLoader: Successfully loaded data for ticker SF1 Curncy with 9802 records.
# 2024-10-22 12:22:07,921 INFO DataLoader: Calculating Carry for SF1 Curncy using carry contract SF2 Curncy
# 2024-10-22 12:22:12,289 INFO DataLoader: Successfully loaded data for ticker SF2 Curncy with 9678 records.
# 2024-10-22 12:22:12,294 INFO DataLoader: Carry calculated and added for SF1 Curncy.
# 2024-10-22 12:22:12,310 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\SF1 Curncy.parquet
# Processing tickers:  82%|████████▏ | 85/104 [16:32<03:06,  9.81s/ticker]2024-10-22 12:22:16,416 INFO DataLoader: Successfully loaded data for ticker NO1 Curncy with 5657 records.
# 2024-10-22 12:22:16,418 INFO DataLoader: Calculating Carry for NO1 Curncy using carry contract NO2 Curncy
# 2024-10-22 12:22:19,387 INFO DataLoader: Successfully loaded data for ticker NO2 Curncy with 5649 records.
# 2024-10-22 12:22:19,392 INFO DataLoader: Carry calculated and added for NO1 Curncy.
# 2024-10-22 12:22:19,406 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\NO1 Curncy.parquet
# Processing tickers:  83%|████████▎ | 86/104 [16:39<02:41,  9.00s/ticker]2024-10-22 12:22:23,067 INFO DataLoader: Successfully loaded data for ticker SE1 Curncy with 5660 records.
# 2024-10-22 12:22:23,069 INFO DataLoader: Calculating Carry for SE1 Curncy using carry contract SE2 Curncy
# 2024-10-22 12:22:25,874 INFO DataLoader: Successfully loaded data for ticker SE2 Curncy with 5649 records.
# 2024-10-22 12:22:25,878 INFO DataLoader: Carry calculated and added for SE1 Curncy.
# 2024-10-22 12:22:25,891 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\SE1 Curncy.parquet
# Processing tickers:  84%|████████▎ | 87/104 [16:45<02:20,  8.25s/ticker]2024-10-22 12:22:28,954 INFO DataLoader: Successfully loaded data for ticker SDE1 Curncy with 1351 records.
# 2024-10-22 12:22:28,956 INFO DataLoader: Calculating Carry for SDE1 Curncy using carry contract SDE2 Curncy
# 2024-10-22 12:22:31,272 INFO DataLoader: Successfully loaded data for ticker SDE2 Curncy with 1351 records.
# 2024-10-22 12:22:31,275 INFO DataLoader: Carry calculated and added for SDE1 Curncy.
# 2024-10-22 12:22:31,288 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\SDE1 Curncy.parquet
# Processing tickers:  85%|████████▍ | 88/104 [16:51<01:58,  7.39s/ticker]2024-10-22 12:22:35,339 INFO DataLoader: Successfully loaded data for ticker NV1 Curncy with 6949 records.
# 2024-10-22 12:22:35,340 INFO DataLoader: Calculating Carry for NV1 Curncy using carry contract NV2 Curncy
# 2024-10-22 12:22:39,118 INFO DataLoader: Successfully loaded data for ticker NV2 Curncy with 6927 records.
# 2024-10-22 12:22:39,123 INFO DataLoader: Carry calculated and added for NV1 Curncy.
# 2024-10-22 12:22:39,137 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-dm\NV1 Curncy.parquet
# Processing tickers:  86%|████████▌ | 89/104 [16:58<01:52,  7.53s/ticker]2024-10-22 12:22:42,817 INFO DataLoader: Successfully loaded data for ticker XUC1 Curncy with 2606 records.
# 2024-10-22 12:22:42,818 INFO DataLoader: Calculating Carry for XUC1 Curncy using carry contract XUC2 Curncy
# 2024-10-22 12:22:46,681 INFO DataLoader: Successfully loaded data for ticker XUC2 Curncy with 2607 records.
# 2024-10-22 12:22:46,685 INFO DataLoader: Carry calculated and added for XUC1 Curncy.
# 2024-10-22 12:22:46,697 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\XUC1 Curncy.parquet
# Processing tickers:  87%|████████▋ | 90/104 [17:06<01:45,  7.54s/ticker]2024-10-22 12:22:52,642 INFO DataLoader: Successfully loaded data for ticker PE1 Curncy with 7461 records.
# 2024-10-22 12:22:52,644 INFO DataLoader: Calculating Carry for PE1 Curncy using carry contract PE2 Curncy
# 2024-10-22 12:22:56,491 INFO DataLoader: Successfully loaded data for ticker PE2 Curncy with 7442 records.
# 2024-10-22 12:22:56,495 INFO DataLoader: Carry calculated and added for PE1 Curncy.
# 2024-10-22 12:22:56,511 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\PE1 Curncy.parquet
# Processing tickers:  88%|████████▊ | 91/104 [17:16<01:46,  8.22s/ticker]2024-10-22 12:23:01,184 INFO DataLoader: Successfully loaded data for ticker XID1 Curncy with 2853 records.
# 2024-10-22 12:23:01,186 INFO DataLoader: Calculating Carry for XID1 Curncy using carry contract XID2 Curncy
# 2024-10-22 12:23:03,852 INFO DataLoader: Successfully loaded data for ticker XID2 Curncy with 2849 records.
# 2024-10-22 12:23:03,857 INFO DataLoader: Carry calculated and added for XID1 Curncy.
# 2024-10-22 12:23:03,872 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\XID1 Curncy.parquet
# Processing tickers:  88%|████████▊ | 92/104 [17:23<01:35,  7.96s/ticker]2024-10-22 12:23:07,421 INFO DataLoader: Successfully loaded data for ticker XTD1 Curncy with 2378 records.
# 2024-10-22 12:23:07,423 INFO DataLoader: Calculating Carry for XTD1 Curncy using carry contract XTD2 Curncy
# 2024-10-22 12:23:10,850 INFO DataLoader: Successfully loaded data for ticker XTD2 Curncy with 2378 records.
# 2024-10-22 12:23:10,853 INFO DataLoader: Carry calculated and added for XTD1 Curncy.
# 2024-10-22 12:23:10,867 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\XTD1 Curncy.parquet
# Processing tickers:  89%|████████▉ | 93/104 [17:30<01:24,  7.67s/ticker]2024-10-22 12:23:21,033 INFO DataLoader: Successfully loaded data for ticker RA1 Curncy with 6881 records.
# 2024-10-22 12:23:21,036 INFO DataLoader: Calculating Carry for RA1 Curncy using carry contract RA2 Curncy
# 2024-10-22 12:23:28,137 INFO DataLoader: Successfully loaded data for ticker RA2 Curncy with 6867 records.
# 2024-10-22 12:23:28,141 INFO DataLoader: Carry calculated and added for RA1 Curncy.
# 2024-10-22 12:23:28,155 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\RA1 Curncy.parquet
# Processing tickers:  90%|█████████ | 94/104 [17:47<01:45, 10.56s/ticker]2024-10-22 12:23:35,601 INFO DataLoader: Successfully loaded data for ticker KO1 Curncy with 4561 records.
# 2024-10-22 12:23:35,603 INFO DataLoader: Calculating Carry for KO1 Curncy using carry contract KO2 Curncy
# 2024-10-22 12:23:41,189 INFO DataLoader: Successfully loaded data for ticker KO2 Curncy with 4547 records.
# 2024-10-22 12:23:41,194 INFO DataLoader: Carry calculated and added for KO1 Curncy.
# 2024-10-22 12:23:41,208 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\KO1 Curncy.parquet
# Processing tickers:  91%|█████████▏| 95/104 [18:00<01:41, 11.31s/ticker]2024-10-22 12:23:45,374 INFO DataLoader: Successfully loaded data for ticker HR1 Curncy with 5443 records.
# 2024-10-22 12:23:45,376 INFO DataLoader: Calculating Carry for HR1 Curncy using carry contract HR2 Curncy
# 2024-10-22 12:23:47,674 INFO DataLoader: Successfully loaded data for ticker HR2 Curncy with 5440 records.
# 2024-10-22 12:23:47,678 INFO DataLoader: Carry calculated and added for HR1 Curncy.
# 2024-10-22 12:23:47,692 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\HR1 Curncy.parquet
# Processing tickers:  92%|█████████▏| 96/104 [18:07<01:18,  9.86s/ticker]2024-10-22 12:23:51,873 INFO DataLoader: Successfully loaded data for ticker A11 Curncy with 4822 records.
# 2024-10-22 12:23:51,875 INFO DataLoader: Calculating Carry for A11 Curncy using carry contract A12 Curncy
# 2024-10-22 12:23:55,833 INFO DataLoader: Successfully loaded data for ticker A12 Curncy with 4715 records.
# 2024-10-22 12:23:55,838 INFO DataLoader: Carry calculated and added for A11 Curncy.
# 2024-10-22 12:23:55,853 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\A11 Curncy.parquet
# Processing tickers:  93%|█████████▎| 97/104 [18:15<01:05,  9.35s/ticker]2024-10-22 12:23:58,345 INFO DataLoader: Successfully loaded data for ticker PLE1 Curncy with 2526 records.
# 2024-10-22 12:23:58,348 INFO DataLoader: Calculating Carry for PLE1 Curncy using carry contract PLE2 Curncy
# 2024-10-22 12:23:59,903 INFO DataLoader: Successfully loaded data for ticker PLE2 Curncy with 2526 records.
# 2024-10-22 12:23:59,906 INFO DataLoader: Carry calculated and added for PLE1 Curncy.
# 2024-10-22 12:23:59,919 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\PLE1 Curncy.parquet
# Processing tickers:  94%|█████████▍| 98/104 [18:19<00:46,  7.76s/ticker]2024-10-22 12:24:04,272 INFO DataLoader: Successfully loaded data for ticker EZ1 Curncy with 5444 records.
# 2024-10-22 12:24:04,275 INFO DataLoader: Calculating Carry for EZ1 Curncy using carry contract EZ2 Curncy
# 2024-10-22 12:24:07,121 INFO DataLoader: Successfully loaded data for ticker EZ2 Curncy with 5441 records.
# 2024-10-22 12:24:07,126 INFO DataLoader: Carry calculated and added for EZ1 Curncy.
# 2024-10-22 12:24:07,140 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\fx-em\EZ1 Curncy.parquet
# Processing tickers:  95%|█████████▌| 99/104 [18:26<00:38,  7.60s/ticker]2024-10-22 12:24:09,060 INFO DataLoader: Successfully loaded data for ticker SSY4 Comdty with 1349 records.
# 2024-10-22 12:24:09,061 INFO DataLoader: Calculating Carry for SSY4 Comdty using carry contract SSY3 Comdty
# 2024-10-22 12:24:10,345 INFO DataLoader: Successfully loaded data for ticker SSY3 Comdty with 1349 records.
# 2024-10-22 12:24:10,348 INFO DataLoader: Carry calculated and added for SSY4 Comdty.
# 2024-10-22 12:24:10,359 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\stir\SSY4 Comdty.parquet
# Processing tickers:  96%|█████████▌| 100/104 [18:30<00:25,  6.29s/ticker]2024-10-22 12:24:12,264 INFO DataLoader: Successfully loaded data for ticker SFI6 Comdty with 1653 records.
# 2024-10-22 12:24:17,494 INFO DataLoader: Successfully loaded data for ticker L 6 Comdty with 8505 records.
# 2024-10-22 12:24:17,496 INFO DataLoader: Stitched data for SFI6 Comdty using old data.
# 2024-10-22 12:24:17,498 INFO DataLoader: Calculating Carry for SFI6 Comdty using carry contract SFI4 Comdty
# 2024-10-22 12:24:19,228 INFO DataLoader: Successfully loaded data for ticker SFI4 Comdty with 1652 records.
# 2024-10-22 12:24:24,845 INFO DataLoader: Successfully loaded data for ticker L 4 Comdty with 8595 records.
# 2024-10-22 12:24:24,848 INFO DataLoader: Stitched data for SFI4 Comdty using old data.
# 2024-10-22 12:24:24,852 INFO DataLoader: Carry calculated and added for SFI6 Comdty.
# 2024-10-22 12:24:24,869 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\stir\SFI6 Comdty.parquet
# Processing tickers:  97%|█████████▋| 101/104 [18:44<00:26,  8.75s/ticker]2024-10-22 12:24:28,062 INFO DataLoader: Successfully loaded data for ticker ER6 Comdty with 6654 records.
# 2024-10-22 12:24:28,064 INFO DataLoader: Calculating Carry for ER6 Comdty using carry contract ER4 Comdty
# 2024-10-22 12:24:32,533 INFO DataLoader: Successfully loaded data for ticker ER4 Comdty with 6654 records.
# 2024-10-22 12:24:32,538 INFO DataLoader: Carry calculated and added for ER6 Comdty.
# 2024-10-22 12:24:32,552 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\stir\ER6 Comdty.parquet
# Processing tickers:  98%|█████████▊| 102/104 [18:52<00:16,  8.43s/ticker]2024-10-22 12:24:36,935 INFO DataLoader: Successfully loaded data for ticker IR6 Comdty with 9055 records.
# 2024-10-22 12:24:36,937 INFO DataLoader: Calculating Carry for IR6 Comdty using carry contract IR4 Comdty
# 2024-10-22 12:24:41,546 INFO DataLoader: Successfully loaded data for ticker IR4 Comdty with 9085 records.
# 2024-10-22 12:24:41,551 INFO DataLoader: Carry calculated and added for IR6 Comdty.
# 2024-10-22 12:24:41,567 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\stir\IR6 Comdty.parquet
# Processing tickers:  99%|█████████▉| 103/104 [19:01<00:08,  8.61s/ticker]2024-10-22 12:24:43,658 INFO DataLoader: Successfully loaded data for ticker SFR8 Comdty with 1631 records.
# 2024-10-22 12:24:49,898 INFO DataLoader: Successfully loaded data for ticker ED8 Comdty with 9201 records.
# 2024-10-22 12:24:49,901 INFO DataLoader: Stitched data for SFR8 Comdty using old data.
# 2024-10-22 12:24:49,902 INFO DataLoader: Calculating Carry for SFR8 Comdty using carry contract SFR6 Comdty
# 2024-10-22 12:24:52,797 INFO DataLoader: Successfully loaded data for ticker SFR6 Comdty with 1631 records.
# 2024-10-22 12:24:57,232 INFO DataLoader: Successfully loaded data for ticker ED6 Comdty with 9347 records.
# 2024-10-22 12:24:57,235 INFO DataLoader: Stitched data for SFR6 Comdty using old data.
# 2024-10-22 12:24:57,241 INFO DataLoader: Carry calculated and added for SFR8 Comdty.
# 2024-10-22 12:24:57,257 INFO DataLoader: Saved data to G:\Projects\BackTesting1.0\Data\Bloomberg\Futures\stir\SFR8 Comdty.parquet
# Processing tickers: 100%|██████████| 104/104 [19:17<00:00, 11.13s/ticker]
# 2024-10-22 12:24:58,264 INFO DataLoader: All data updated successfully.

# %%
# Define paths to auxiliary data for MarketData
tick_values_path = os.path.join(helper_directory, 'fut_val_pt.parquet')
fx_rates_path = os.path.join(helper_directory, 'fxHist.parquet')

# Initialize the MarketData
market_data = MarketData(
    base_directory=save_directory,
    tick_values_path=tick_values_path,
    fx_rates_path=fx_rates_path,
    instrument_type="Futures",
    n_threads=8,  # Number of threads for parallel data loading
    log_level=logging.ERROR  # Set to DEBUG for more detailed logs
)

# %%
# Access data for a specific ticker
try:
    test_df = market_data.get_ticker_data('LP1 Comdty')
    print(test_df)
except ValueError as e:
    print(e)

# Access all preprocessed data
all_data = market_data.get_data()
print(f"Total tickers loaded: {len(all_data)}")

# Access FX rates
fx_rates = market_data.get_fx_rates()
# Access tick values
tick_values = market_data.get_tick_values()
# Access asset classes
asset_classes = market_data.get_asset_classes()

# %%
test_df

# %%
from btEngine2.Rules.Momentum.sbo_long import *

sboParams1 = {
    'X': 21,
    'N': 5,
    'r': 0.75,
    'atr_type': 'atr'
}

pSizeParams = {
    'AssetVol': 1_200_000,  # Target asset volatility in USD
    'VolLookBack': 125  # Lookback period for volatility calculation
}

pSizeParams2 = {
    'AssetVol': r'G:\Projects\BackTesting1.0\Data\Inputs\AssetSizing-Futs.csv',  # Target asset volatility in USD
    'VolLookBack': 125  # Lookback period for volatility calculation
}

# %%
test = sbo_long(test_df, **sboParams1)

# %%
test

# %%
test.to_pandas().to_clipboard()

# %%
asset_classes

# %%
market_data.get_asset_classes()['comm-enrgy']

# %%
fx_rates
